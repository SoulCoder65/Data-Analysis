# %% [markdown]
# # POLICE DATA SETS

# %%
import pandas as pd

# %%
# import datasets
police_ds=pd.read_csv("../CSV/policdata.csv")

# %%
police_ds.head(5)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
police_ds.describe().transpose()
# Out:
#                   count         mean         std   min     25%     50%  \
# country_name        0.0          NaN         NaN   NaN     NaN     NaN
# driver_age_raw  61481.0  1967.791106  121.050106   0.0  1965.0  1978.0
# driver_age      61228.0    34.148984   12.760710  15.0    23.0    31.0
#
#                    75%     max
# country_name       NaN     NaN
# driver_age_raw  1985.0  8801.0
# driver_age        43.0    88.0

# %%
police_ds.shape
# Out:
# (65535, 15)

# %% [markdown]
# ## Instruction ( For Data Cleaning ) - Remove the column that only contains missing values.

# %%
police_ds.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
police_ds.drop(columns="country_name",inplace=True)

# %%
police_ds
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# ## Question ( Based on Filtering + Value Counts ) - For Speeding , were Men or Women stopped more often ?

# %%
police_ds.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %% [markdown]
# ## Question ( mapping + data-type casting ) - What is the mean stop_duration ?

# %%
police_ds['stop_duration'].value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
police_ds['stop_duration']=police_ds['stop_duration'].map({"0-15 Min":7.5,"16-30 Min":15,"30+ Min":45})

# %%
police_ds.groupby('stop_duration').mean()
# Out:
#                driver_age_raw  driver_age  search_conducted  \
# stop_duration
# 7.5               1968.724682   34.021884          0.012959
# 15.0              1963.929245   34.120067          0.098270
# 45.0              1969.254628   36.548448          0.279562
#
#                drugs_related_stop
# stop_duration
# 7.5                      0.002596
# 15.0                     0.018955
# 45.0                     0.067246

# %% [markdown]
# ## Question ( Groupby , Describe ) - Compare the age distributions for each violation.

# %%
police_ds.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
