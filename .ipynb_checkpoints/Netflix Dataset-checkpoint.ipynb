# %% [markdown]
# # NETFLIX DATASET

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
netflix_df=pd.read_csv("../CSV/netflixdata.csv")

# %%
netflix_df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
netflix_df.describe()
# Out:
#        Show_Id Category              Title                Director  \
# count     7789     7789               7789                    5401
# unique    7787        2               7787                    4050
# top       s684    Movie  The Lost Okoroshi  Raúl Campos, Jan Suter
# freq         2     5379                  2                      18
#
#                       Cast        Country     Release_Date Rating  Duration  \
# count                 7071           7282             7779   7782      7789
# unique                6831            681             1565     14       216
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    18           2556              118   2865      1608
#
#                  Type                                        Description
# count            7789                                               7789
# unique            492                                               7769
# ...

# %%
netflix_df.shape
# Out:
# (7789, 11)

# %%
netflix_df.size
# Out:
# 85679

# %% [markdown]
# ## Is there any Null Value present in any column ? Show with Heat-map

# %%
netflix_df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
plt.figure(figsize=(25,15))
sns.heatmap(data=netflix_df.isnull());

# %% [markdown]
# ##  1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
netflix_df[netflix_df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
netflix_df=netflix_df.drop_duplicates()

# %%
netflix_df[netflix_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ## For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
netflix_df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
netflix_df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
netflix_df[netflix_df["Title"]=="House of Cards"][{"Show_Id","Director"}]
# Out:
#                                                Director Show_Id
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...   s2833

# %% [markdown]
# ##  In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
year=pd.to_datetime(netflix_df["Release_Date"])

# %%
netflix_df["year"]=year.dt.year

# %%
netflix_df.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
netflix_df["year"].value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: year, dtype: int64

# %% [markdown]
# ## Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
netflix_df.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(netflix_df["Category"]);
# Out:
# C:\Users\soulc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Q. 4) Show all the Movies that were released in year 2016.

# %%
netflix_df[(netflix_df["Category"]=="Movie")& (netflix_df["year"]==2016) ]
# Out:
#      Show_Id Category                    Title  \
# 1         s2    Movie                    07:19
# 25       s26    Movie                 (T)ERROR
# 35       s36    Movie                #Rucker50
# 59       s60    Movie          1000 Rupee Note
# 62       s63    Movie               13 Cameras
# ...      ...      ...                      ...
# 7715   s7714    Movie  Yo-Kai Watch: The Movie
# 7716   s7715    Movie              Yoga Hosers
# 7728   s7727    Movie             You Carry Me
# 7739   s7738    Movie              Young Tiger
# 7772   s7771    Movie                  Zinzana
#
#                                     Director  \
# 1                          Jorge Michel Grau
# 25    Lyric R. Cabral, David Felix Sutcliffe
# 35                     Robert McCullough Jr.
# 59                            Shrihari Sathe
# 62                            Victor Zarcoff
# ...                                      ...
# 7715                             Mark Risley
# ...

# %% [markdown]
# ## Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
netflix_df[(netflix_df["Category"]=="TV Show") & (netflix_df["Country"]=="India")]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ## Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df=netflix_df["Director"].value_counts()

# %%
df.head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Name: Director, dtype: int64

# %% [markdown]
# ## Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
netflix_df[(((netflix_df["Type"].str.contains("Comedies")) &(netflix_df["Category"]=="Movie")) |(netflix_df["Country"]=="United Kingdom"))]
# Out:
#      Show_Id Category                              Title            Director  \
# 18       s19    Movie                             15-Aug  Swapnaneel Jayakar
# 19       s20    Movie                                '89                 NaN
# 33       s34    Movie                       #realityhigh    Fernando Lebrija
# 34       s35    Movie                              #Roxy     Michael Kennedy
# 36       s37    Movie                            #Selfie      Cristina Jacob
# ...      ...      ...                                ...                 ...
# 7766   s7765    Movie                               Zero          Aanand Rai
# 7771   s7770    Movie           Zindagi Na Milegi Dobara         Zoya Akhtar
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan        Oskar Santos
# 7780   s7779    Movie                         Zombieland     Ruben Fleischer
# 7783   s7782    Movie                               Zoom        Peter Hewitt
#
# ...

# %% [markdown]
# ## Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
netflix_df=netflix_df.dropna()
netflix_df[netflix_df["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description    year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# ## Q. 9) What are the different Ratings defined by Netflix ?

# %%
netflix_df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
netflix_df["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
netflix_df[(netflix_df["Category"]=="Movie")&(netflix_df["Rating"]=="TV-14")& (netflix_df["Country"]=="Canada")]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %% [markdown]
# ## Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
netflix_df[(netflix_df["Category"]=="TV Show") & (netflix_df["Rating"]=="TV-MA")& (netflix_df["year"]>2018)]
# Out:
#      Show_Id Category                                         Title  \
# 426     s427  TV Show                                  Almost Happy
# 531     s532  TV Show                       Anitta: Made In Honório
# 805     s806  TV Show                                     Before 30
# 941     s942  TV Show                                Bitter Daisies
# 958     s959  TV Show                              Black Money Love
# 1028   s1029  TV Show                                       Bolívar
# 1181   s1182  TV Show                              Call the Midwife
# 1525   s1526  TV Show                           Crazy, Lovely, Cool
# 1534   s1535  TV Show                      Crime Diaries: Night Out
# 1540   s1541  TV Show                               Criminal: Spain
# 1720   s1721  TV Show                                     Detention
# 2117   s2118  TV Show                               Fary : Hexagone
# 2139   s2140  TV Show                                     Feel Good
# ...

# %% [markdown]
# ## Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
netflix_df["Duration"].unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
netflix_df[["Count","Unit"]]=netflix_df["Duration"].str.split(" ",expand=True)

# %%
netflix_df.sort_values(by="Count",ascending=False)
# Out:
#      Show_Id Category                                              Title  \
# 1811   s1812    Movie                        Don't Be Afraid of the Dark
# 6716   s6715    Movie                 The Nutcracker and the Four Realms
# 4352   s4353    Movie                               My Scientology Movie
# 5421   s5421    Movie                                           Say When
# 4366   s4367    Movie                               My Week with Marilyn
# ...      ...      ...                                                ...
# 4604   s4605  TV Show  Oliver Stone's Untold History of the United St...
# 4603   s4604  TV Show                                          Old Money
# 2380   s2381  TV Show                                   Geronimo Stilton
# 7387   s7386  TV Show                                            Valeria
# 5962   s5962  TV Show                               Take My Brother Away
#
#                            Director  \
# 1811                     Troy Nixey
# ...

# %% [markdown]
# ## Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
netflix_df.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description    year Count Unit
# ...

# %%
netflix_df[netflix_df["Category"]=="TV Show"].Country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# South Korea                                                      10
# Japan                                                            10
# Spain                                                             7
# Taiwan                                                            6
# India                                                             5
# Turkey                                                            5
# Brazil                                                            4
# Nigeria                                                           3
# Canada                                                            3
# France                                                            3
# Thailand                                                          3
# Italy                                                             2
# ...

# %% [markdown]
# ## Q. 12) How can we sort the dataset by Year ?

# %%
netflix_df.sort_values(by="year")
# Out:
#      Show_Id Category                              Title  \
# 7115   s7114    Movie               To and From New York
# 5766   s5766    Movie                           Splatter
# 3248   s3249    Movie            Just Another Love Story
# 3840   s3841    Movie        Mad Ron's Prevues from Hell
# 3221   s3222    Movie             Joseph: King of Dreams
# ...      ...      ...                                ...
# 1426   s1427    Movie  Cloudy with a Chance of Meatballs
# 1739   s1740    Movie        Dhobi Ghat (Mumbai Diaries)
# 7553   s7552    Movie          What Happened to Mr. Cha?
# 2479   s2480    Movie                          Good Hair
# 3237   s3238    Movie                      Julie & Julia
#
#                            Director  \
# 7115           Sorin Dan Mihalcescu
# 5766                      Joe Dante
# 3248                   Ole Bornedal
# 3840                     Jim Monaco
# 3221  Rob LaDuca, Robert C. Ramirez
# ...                             ...
# ...
