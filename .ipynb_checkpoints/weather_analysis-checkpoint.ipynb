# %% [markdown]
# # WEATHER ANALYSIS

# %%
# Imports libraris

# %%
import seaborn as sns
import pandas as pd

# %%
# import csv file

# %%
 weather_data=pd.read_csv("../CSV/weatherData.csv")

# %%
weather_data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather  clear
# 0            8.0     101.24                   Fog  False
# 1            8.0     101.24                   Fog  False
# 2            4.0     101.26  Freezing Drizzle,Fog  False
# 3            4.0     101.27  Freezing Drizzle,Fog  False
# 4            4.8     101.23                   Fog  False

# %%
weather_data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ## Find all the unique 'Wind Speed' values in the data.

# %%
weather_data['Wind Speed_km/h'].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 48     13
# 43     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 70      1
# 54      1
# 83      1
# 63      1
# Name: Wind Speed_km/h, dtype: int64

# %%
weather_data['Wind Speed_km/h'].nuniqueique()
# Out:
# 34

# %% [markdown]
# ## Find the number of times when the 'Weather is exactly Clear'.

# %%
weather_data['clear']=weather_data['Weather']=="Clear"
weather_data['clear'].value_counts()[1]
# Out:
# 1326

# %%
weather_data['Weather'].value_counts()['Clear']
# Out:
# 1326

# %% [markdown]
# ## Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
weather_data['Wind Speed_km/h'].value_counts()[4]
# Out:
# 474

# %% [markdown]
# ## Find out all the Null Values in the data.

# %%
weather_data.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather  clear
# 0             False      False    False  False
# ...

# %% [markdown]
# ## Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
weather_data.rename(columns={"Weather":"Weather Condition"},inplace=True)

# %%
weather_data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa     Weather Condition  clear
# 0            8.0     101.24                   Fog  False
# 1            8.0     101.24                   Fog  False
# ...

# %% [markdown]
# ## What is the mean 'Visibility' ?

# %%
weather_data['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# ## What is the Standard Deviation of 'Pressure'  in this data?

# %%
weather_data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# ## What is the Variance of 'Relative Humidity' in this data ?

# %%
weather_data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# ## Find all instances when 'Snow' was recorded.

# %%
weather_data[weather_data['Weather Condition']=="Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'

# %%
weather_data[(weather_data['Wind Speed_km/h']>=24) & (weather_data['Visibility_km']>=25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# ## What is the Mean value of each column against each 'Weather Condition

# %%
weather_data.groupby("Weather Condition").mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# ## What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
weather_data.groupby("Weather Condition").aggregate(['max','min'])
# Out:
#                                                 Date/Time                    \
#                                                       max               min
# Weather Condition
# Clear                                       9/9/2012 5:00    1/11/2012 1:00
# Cloudy                                     9/9/2012 23:00    1/1/2012 17:00
# Drizzle                                    9/30/2012 3:00   1/23/2012 21:00
# Drizzle,Fog                                9/30/2012 2:00   1/23/2012 20:00
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00   12/17/2012 9:00
# Drizzle,Snow                             12/19/2012 18:00  12/17/2012 15:00
# Drizzle,Snow,Fog                          12/22/2012 3:00  12/18/2012 21:00
# Fog                                        9/22/2012 0:00     1/1/2012 0:00
# Freezing Drizzle                            2/1/2012 5:00   1/13/2012 10:00
# Freezing Drizzle,Fog                      12/10/2012 5:00     1/1/2012 2:00
# ...

# %% [markdown]
# ## Show all the Records where Weather Condition is Fog.

# %%
weather_data[weather_data['Weather Condition']=="Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %% [markdown]
# ## Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
weather_data[(weather_data['Weather Condition']=="Clear") | (weather_data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# ## Find all instances when :
# ## A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# ## or
# ## B. 'Visibility is above 40'

# %%
weather_data[((weather_data['Weather Condition']=="Clear") & (weather_data['Rel Hum_%']>50)) | (weather_data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
